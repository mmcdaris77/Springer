# %%
import spacy
from spacy import displacy
import os 
import json

me_dir = os.path.dirname(os.path.abspath("use_model.ipynb"))

nlp = spacy.load(os.path.join(me_dir, 'drug_ner_pipe'))

data = [
    "Anastrozole 1 mg orally once daily for 5 years",
    "Palbociclib 125 mg orally once daily for 21 days, followed by 7 days off, in combination with Letrozole",
    "Doxorubicin 60 mg/m and Cyclophosphamide 600 mg/m² IV every 3 weeks for 4 cycles (neoadjuvant chemotherapy)",
    "Paclitaxel 80 mg/m² IV weekly for 12 weeks in combination with Herceptin (trastuzumab)",
    "Carboplatin AUC 6 IV every 3 weeks in combination with Docetaxel 75 mg/m² IV every 3 weeks for 6 cycles",
    "Capecitabine 1250 mg/m² orally twice daily for 14 days followed by 7 days off",
    "Fulvestrant 500 mg IM on days 1, 15, and 29, then monthly",
    "Palbociclib 125 mg orally once daily for 21 days, followed by 7 days off, in combination with Exemestane",
    "Docetaxel 75 mg/m² IV every 3 weeks for 4 cycles, Carboplatin AUC 6 IV every 3 weeks for 4 cycles, and Trastuzumab (Herceptin) IV every 3 weeks for 18 cycles (adjuvant chemotherapy)",
    "Trastuzumab (Herceptin) IV every 3 weeks for an additional 18 cycles (maintenance therapy)",
    "Aspirin 200.5 mg twice a day for 2 weeks", 
    "Aspirin .5 tablet twice a day", 
    "Aspirin .5 pmol/g twice a day", 
    "Aspirin .5 dyne/s/cm5 twice a day for 2.5 weeks"
    
]

docs = []
for i, d in enumerate(data): 
    docs.append(nlp(d))
    #print([(ent.text, ent.label_, ent.ent_id_) for ent in doc.ents])

#print(json.dumps(docs[0].to_json(), indent=4))
#for e in docs[0].ents:
#    print(f'text: {e.text}  ->  label: {e.label_}')

colors = {'drg': "#85C1E9", "rte": "#ff6961", "dose": "#96944d", "frq": "#5a3869", "dur": "#385469", "cycl": "#3a7a4b"}
options = {"ents": ['drg', 'rte', 'dose', 'frq', 'dur', 'cycl'], "colors": colors}
print("Tag regimens (regimens generated by ChatGPT for testing!)")
displacy.render(docs, style="ent", options=options)
# Out:
# Tag regimens (regimens generated by ChatGPT for testing!)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #85C1E9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anastrozole
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRG</span>
# </mark>
#
# <mark class="entity" style="background: #96944d; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 mg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DOSE</span>
# </mark>
#
# <mark class="entity" style="background: #ff6961; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     orally
# ...
